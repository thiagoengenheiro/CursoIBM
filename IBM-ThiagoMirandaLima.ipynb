# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Thiago Miranda Lima
# Engenheiro da Computação

# %% [markdown]
# _Estou interessado em ciência de dados porque é a minha área de atuação durante a maioria do tempo na minha carreira e sou apaixonado pelo tema_

# %% [markdown]
# ### O Código abaixo é uma função que retorna a área de um quadrado / retângulo de lado l e comprimento c

# %%
def area(l,c):
    return f'A área é: {l*c}'

area(3,4)
# Out:
# 'A área é: 12'

# %% [markdown]
# <hr> Olá, este é meu primeiro exercicio prático do Jupyter Notebook </hr>
# <blockquote> Thiago Miranda Lima
#     <a href="mailto:thiagomlima@gmail.com"> Contato </a>
# </blockquote>
